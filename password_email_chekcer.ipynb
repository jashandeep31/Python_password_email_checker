# %%
import re

# %%
email = ['123ghatrora123@gmail.com','jashan@j.com']

for i in email:  
  print(re.search("[a-z0-9!#$%&'*+/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+/=?^_`{|}~-]+)*@(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?",i))

passwords = ['Tummereho@12',"merenahihho","Testing193!"]
# Out:
# <re.Match object; span=(0, 24), match='123ghatrora123@gmail.com'>
# <re.Match object; span=(0, 12), match='jashan@j.com'>

# %%
for i in passwords:
  try:
    print(re.search("^(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[@$!%*#?&])[A-Za-z\d@$!#%*?&]{6,20}$",i))
  except:
    print("Please enter the strong password")
# Out:
# <re.Match object; span=(0, 12), match='Tummereho@12'>
# None
# <re.Match object; span=(0, 11), match='Testing193!'>
